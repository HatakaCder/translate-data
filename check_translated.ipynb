# %%
import pandas as pd

# %%
pd.read_json('example_translated.json')
# Out:
#          id                                               name  \
# 0       S_1                                  Đại học Thanh Hoa
# 1       S_2                                   Đại học Bắc Kinh
# 2       S_3                                     Đại học Vũ Hán
# 3       S_4                                    Đại học Soochow
# 4       S_5                                   Đại học Tứ Xuyên
# ..      ...                                                ...
# 424  S_1402                                 Đại học Y Cao Hùng
# 425  S_1405  Cao đẳng nghề khai hoang nông nghiệp Hắc Long ...
# 426  S_1448             Đại học Tài chính và Kinh tế Giang Tây
# 427  S_1453     Cao đẳng kỹ thuật và dạy nghề vận tải Quý Châu
# 428  S_1455  Đại học Y học cổ truyền Trung Quốc Hắc Long Giang
#
#                                                name_en  \
# 0                                  Tsinghua University
# 1                                    Peking University
# ...
