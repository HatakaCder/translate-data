# %%
import pandas as pd

# %%
pd.read_json('example_translated.json')
# Out:
#          id                                         name  \
# 30     S_34  Đại học Thiên Tân của Trung Quốc nước ngoài
# 31     S_35                               Đại học Nankai
# 32     S_36       Đại học Khoa học và Công nghệ Côn Minh
# 33     S_37                   Viện Công nghệ Cáp Nhĩ Tân
# 34     S_38               Đại học Nông nghiệp Trung Quốc
# ..      ...                                          ...
# 424  S_1402                                       高雄医学大学
# 425  S_1405                                    黑龙江农垦职业学院
# 426  S_1448                                       江西财经大学
# 427  S_1453                                   贵州交通职业技术学院
# 428  S_1455                                     黑龙江中医药大学
#
#                                                name_en  \
# 30                  Tianjin Foreign Studies University
# 31                                   Nankai University
# 32        Kunming University of Science and Technology
# ...
